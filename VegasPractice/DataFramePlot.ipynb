// %%
import $ivy.`org.vegas-viz::vegas:0.3.11`

import $ivy.`org.vegas-viz::vegas-spark:0.3.11`
// Out:
// import $ivy.$
//
//
// import $ivy.$

// %%
import vegas._

import vegas.render.WindowRenderer._
// Out:
// import vegas._
//
//
// import vegas.render.WindowRenderer._

// %%
import $ivy.`org.apache.spark::spark-sql:2.4.0`
// Out:
// import $ivy.$

// %%
import org.apache.spark.SparkContext._

import org.apache.spark.rdd._

import org.apache.spark.util.LongAccumulator

import org.apache.log4j._

import org.apache.spark.sql._
// Out:
// import org.apache.spark.SparkContext._
//
//
// import org.apache.spark.rdd._
//
//
// import org.apache.spark.util.LongAccumulator
//
//
// import org.apache.log4j._
//
//
// import org.apache.spark.sql._

// %%
Logger.getLogger("org").setLevel(Level.ERROR)

val spark = SparkSession

.builder

.appName("Vegas")

.master("local[*]")
.getOrCreate()

//and SparkContext sc

val sc = spark.sparkContext
// Out:
// spark: SparkSession = org.apache.spark.sql.SparkSession@480be23b
// sc: org.apache.spark.SparkContext = org.apache.spark.SparkContext@609c8b0a

// %%
import $ivy.`org.apache.spark::spark-mllib:2.4.0`

//now import Vegas-viz library

import vegas._

import vegas.data.External._

//Generate random dataset
// Out:
// import $ivy.$
//
// //now import Vegas-viz library
//
//
// import vegas._
//
//
// import vegas.data.External._
//
// //Generate random dataset

// %%
import scala.math._

var X=Array[Double]()

var Y=Array[Double]()

for (i <- 0 until 100)

{

var x=random*10

var b=random*10

X :+= x

Y :+=3*x+b

}
// Out:
// import scala.math._
//
//
// X: Array[Double] = Array(
//   1.7736902033160473,
//   4.411719371312502,
//   6.4045435689035735,
//   1.6761507843638335,
//   6.681522291677514,
//   7.126711885824204,
//   8.71933993632921,
//   8.945139225147635,
//   6.957315140228639,
//   6.572170017545779,
//   2.3542617584380485,
//   5.896129575617273,
//   1.9814358666047505,
//   6.477547852575265,
//   6.9266870358626615,
//   6.067677390991966,
//   9.378040701914456,
//   2.4151132637625805,
//   7.772513579081346,
//   6.1535474304570155,
//   0.9760431149341087,
//   1.425011901331018,
//   8.602991663901449,
//   2.816801193878571,
//   4.788761461607104,
//   8.176583788509053,
//   6.996638334451256,
//   6.919047572292209,
//   9.770054883917048,
//   2.5487495256991655,
//   5.734048056840415,
//   6.297666332749529,
//   2.6047602427702596,
//   6.012275097336298,
//   5.4834107386114255,
//   0.7238173246036772,
//   8.291245439973368,
//   6.696728932201358,
// ...
// Y: Array[Double] = Array(
//   5.547212727725445,
//   18.347103295627704,
//   26.718212022153608,
//   13.665716737074993,
//   29.84466343962444,
//   22.39773133352412,
//   26.632401697399633,
//   29.88544618238029,
//   30.06578978524356,
//   26.402059210859072,
//   12.746915890003468,
//   24.67998630837585,
//   15.253364407103263,
//   19.561646155243693,
//   28.790687128977037,
//   27.7792939144505,
//   28.56413677263453,
//   12.39393370772208,
//   25.192660987584365,
//   21.696782733091343,
//   11.136587891010533,
//   6.400179776286824,
//   27.50888338091174,
//   11.71829641677915,
//   23.788282766505176,
//   32.46141299391019,
//   28.851052147048375,
//   29.540987952883462,
//   36.38655945674555,
//   15.306171097144185,
//   21.160281093470097,
//   22.905849478571987,
//   14.736306568235364,
//   21.39376200739195,
//   20.169832289810977,
//   3.567643322283056,
//   34.828586087921344,
//   27.556803433288202,
// ...

// %%
import spark.implicits._
// Out:
// import spark.implicits._

// %%
val df = sc.parallelize(X zip Y).toDF("features","label").sort("features")

df.show(3)
// Out:
// +-------------------+-----------------+
// |           features|            label|
// +-------------------+-----------------+
// |0.04831959752722437|8.801348754532462|
// |0.05289121816632325|4.414988545681114|
// |0.13418703897343565|6.622927140837889|
// +-------------------+-----------------+
// only showing top 3 rows
// df: Dataset[Row] = [features: double, label: double]

// %%
import vegas._

import vegas.render.WindowRenderer._

import vegas.sparkExt._
// Out:
// import vegas._
//
//
// import vegas.render.WindowRenderer._
//
//
// import vegas.sparkExt._

// %%
val plot = Vegas("linear regression",width=800, height=600).

withDataFrame(df).
mark(Point).

encodeX("features", Quantitative).

encodeY("label", Quantitative).

show
// Out:
//   <iframe id="frame-vegas-62d640c8-50f1-435a-8f49-3782c080b4a2" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-62d640c8-50f1-435a-8f49-3782c080b4a2'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;width&quot; : 800.0,
//   &quot;height&quot; : 600.0,
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;features&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;label&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;linear regression&quot;,
//   &quot;data&quot; : {
//     &quot;values&quot; : [
//       {
//         &quot;features&quot; : 0.04831959752722437,
//         &quot;label&quot; : 8.801348754532462
//       {
//         &quot;features&quot; : 2.5487495256991655,
//         &quot;label&quot; : 15.306171097144185
//       },
//       {
//         &quot;features&quot; : 2.6047602427702596,
//         &quot;label&quot; : 14.736306568235364
//       },
//       {
//         &quot;features&quot; : 2.816144067221801,
//         &quot;label&quot; : 9.586691571212624
//       },
//       {
//         &quot;features&quot; : 2.816801193878571,
//         &quot;label&quot; : 11.71829641677915
//       },
//       {
//         &quot;features&quot; : 3.1426796086239506,
//         &quot;label&quot; : 14.938875030068886
//       },
//       {
//         &quot;features&quot; : 3.2138603231498317,
//         &quot;label&quot; : 13.861634735888696
//       },
//       {
//         &quot;features&quot; : 3.5280279977140108,
//         &quot;label&quot; : 13.432594640334692
//       },
//       {
//         &quot;features&quot; : 3.588200812824629,
//         &quot;label&quot; : 20.397832543113513
//       },
//       {
//         &quot;features&quot; : 3.71400850809793,
//         &quot;label&quot; : 13.686905017591034
//       },
//       {
//         &quot;features&quot; : 3.7947516714949137,
//         &quot;label&quot; : 19.265704725137685
//       },
//       {
//         &quot;features&quot; : 4.411719371312502,
//         &quot;label&quot; : 18.347103295627704
//       },
//       {
//         &quot;features&quot; : 4.788761461607104,
//         &quot;label&quot; : 23.788282766505176
//       },
//       {
//         &quot;features&quot; : 4.925226763301912,
//         &quot;label&quot; : 17.214796020779705
//       },
//       {
//         &quot;features&quot; : 5.093896821519655,
//         &quot;label&quot; : 16.44342389324417
//       },
//       {
//         &quot;features&quot; : 5.174049374648982,
//         &quot;label&quot; : 15.945988823600295
//       },
//       {
//         &quot;features&quot; : 5.478361336330106,
//         &quot;label&quot; : 22.0584132659256
//       },
//       {
//         &quot;features&quot; : 5.4834107386114255,
//         &quot;label&quot; : 20.169832289810977
//       },
//       {
//         &quot;features&quot; : 5.5249450542197724,
//         &quot;label&quot; : 17.74679264030141
//       },
//       {
//         &quot;features&quot; : 5.550647464442877,
//         &quot;label&quot; : 18.478151858764136
//       },
//       {
//         &quot;features&quot; : 5.734048056840415,
//         &quot;label&quot; : 21.160281093470097
//       },
//       {
//         &quot;features&quot; : 5.7493429669800955,
//         &quot;label&quot; : 21.328799015472118
//       },
//       {
//         &quot;features&quot; : 5.896129575617273,
//         &quot;label&quot; : 24.67998630837585
//       },
//       {
//         &quot;features&quot; : 5.9065585591777765,
//         &quot;label&quot; : 23.322900088876903
//       },
//       {
//         &quot;features&quot; : 5.994812472265371,
//         &quot;label&quot; : 21.974936653263807
//       },
//       {
//         &quot;features&quot; : 6.012275097336298,
//         &quot;label&quot; : 21.39376200739195
//       },
//       {
//         &quot;features&quot; : 6.067677390991966,
//         &quot;label&quot; : 27.7792939144505
//       },
//       {
//         &quot;features&quot; : 6.1535474304570155,
//         &quot;label&quot; : 21.696782733091343
//       },
//       {
//         &quot;features&quot; : 6.297666332749529,
//         &quot;label&quot; : 22.905849478571987
//       },
//       {
//         &quot;features&quot; : 6.343080845905988,
